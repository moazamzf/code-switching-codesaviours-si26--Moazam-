# %% [markdown]
# <a href="https://colab.research.google.com/github/moazamzf/code-switching-codesaviours-si26--Moazam-/blob/main/SI26_Week6_Moazam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Semi-automatic labeling helper for Roman Urdu / English code-switching dataset
# Paste this into your Colab notebook.

import pandas as pd
import re

# ---- STEP 1: paste your raw sentences here ----
sentences = [
    "Aaj mera mood nahi hai for anything",
    "Yaar seriously I can't even right now, bohot thak gaya hoon",
    "Bhai kal mera presentation hai, still not prepared at all",
    "Khana kha liya? I was literally waiting for you",
    "Assignment submit ho gaya finally, huge relief",
    "Mujhe pata tha you would say that",
    "Traffic itna zyada tha, I was stuck for an hour",
    "Weekend pe kuch plan hai ya bore hoga ghar pe?",
    "Exam ka result aaya, I'm so nervous",
    "Yeh movie bilkul boring thi, waste of time",
    "Class miss ho gayi kyunki I overslept",
    "Bhai tension mat lo, everything will be fine",
    "Mujhe ye job offer mila, can't believe it",
    "Ghar pe koi nahi hai, it's so quiet",
    "Kal se diet start karni hai, seriously this time",
    "She's so talented, mujhe jealous feel hota hai",
    "Chai pi lo, it'll help with the headache",
    "Meeting postpone ho gayi, thank god",
    "I need a break, bohot zyada kaam ho gaya hai",
    "Us ne mujhe reply hi nahi kiya, so rude",
    "Bohot mehnga hai yeh, not worth the price",
    "Are you free tomorrow? Mujhe kuch discuss karna hai",
    "Phone gir gaya aur screen crack ho gayi, ugh",
    "I finally finished the project, alhamdulillah",
    "Bahar bohot garmi hai, can't go out right now",
    "Uska birthday hai next week, gift lena hai",
    "Trust me, yeh idea kaam nahi karega",
    "Mujhe thoda time do, I'll figure it out",
    "Kal raat neend hi nahi aayi, so tired today",
    "This place is amazing, humein zaroor jana chahiye",
    "Woh dobara late aaya, I'm getting annoyed now",
    "Weather bohot acha hai today, let's go for a walk",
    "Mujhe samajh nahi aa raha, can you explain again?",
    "She just texted me, guess what she said",
    "Internet down hai since morning, so frustrating",
    "Kal se gym start karni hai, no more excuses",
    "I already told him, usne suna hi nahi",
    "Yeh dress kaisi lagti hai, honest opinion do",
    "Bill bohot zyada aaya is mahine, kharcha kam karna hoga",
    "Can we reschedule? Kal mera doctor ke paas jana hai",
    "Sab kuch theek ho jayega, don't worry so much",
    "Naya phone lena hai, but budget tight hai",
    "I can't focus today, dimaag kahin aur hai",
    "Usne mujhse jhoot bola, I'm so disappointed",
    "Ye recipe try ki maine, turned out really well",
    "Traffic signal kharab hai, everyone's just going crazy",
    "Honestly speaking, mujhe yeh plan pasand nahi aaya",
    "Flight delay ho gayi, ab kya karein",
    "She's moving to another city, I'll miss her a lot",
    "Bas kar do ab, enough is enough yaar",
    "Aaj weather bohat acha hai, chalo bahar walk pe chalte hain",
    "Tum ne mera message abhi tak read nahi kiya?",
    "Yaar mujhe ye assignment samajh nahi aa rahi",
    "Kal university mein presentation hai, tayari ho gayi?",
    "Please mujhe bata dena jab tum ghar pohanch jao",
    "Main abhi busy hoon, thori der baad call karta hoon",
    "Tumhara internet itna slow kyun chal raha hai?",
    "Aaj mujhe market se kuch groceries leni hain",
    "Bhai ye laptop kaafi expensive hai, koi cheaper option hai?",
    "Mujhe lagta hai ke hum kal movie dekhne ja sakte hain",
    "Tum ne breakfast kiya ya abhi tak nahi?",
    "Please file mujhe WhatsApp par send kar dena",
    "Aaj class mein teacher ne bohat important topic explain kiya",
    "Mera phone battery low hai, charger kahan hai?",
    "Agar tum free ho to mujhe call kar lena",
    "Ye game mere laptop par smoothly run nahi kar rahi",
    "Main kal se apna routine change karne ka soch raha hoon",
    "Tumhara result kab announce hona hai?",
    "Yaar mujhe aaj bohat zyada thakan ho rahi hai",
    "Is project ko complete karne mein kitna time lagega?",
    "Mujhe online shopping ke liye ye website achi lagti hai",
    "Tum please mujhe iska screenshot send kar do",
    "Aaj dinner mein kya bana hai?",
    "Main abhi university se wapas aa raha hoon",
    "Kal meeting exactly kis time start hogi?",
    "Mujhe apne computer mein new software install karna hai",
    "Tum tension mat lo, sab kuch theek ho jayega",
    "Yaar ye problem jitni easy lag rahi thi utni hai nahi",
    "Main weekend par apne friends ke saath outing par jaunga",
    "Kya tum mujhe is question ka answer explain kar sakte ho?",
    "Aaj traffic bohat zyada hai, late ho sakte hain",
    "Mujhe apni files ka backup banana chahiye",
    "Tum ne assignment submit kar diya ya abhi pending hai?",
    "Please door lock kar dena jab tum bahar jao",
    "Main YouTube par ek interesting tutorial dekh raha tha",
    "Ye restaurant ka food surprisingly bohat tasty hai",
    "Tumhara favorite programming language kaunsa hai?",
    "Mujhe Python ka syntax kaafi easy lagta hai",
    "Kal se main daily exercise start karunga",
    "Agar weather acha raha to hum cricket khelenge",
    "Mujhe ye shoes pasand hain lekin price bohat high hai",
    "Tum ne apna room clean kiya ya nahi?",
    "Main thori der mein tumhare paas aa raha hoon",
    "Yaar mujhe samajh nahi aa raha ke ye code error kyun de raha hai",
    "Is laptop ki performance normal use ke liye kaafi achi hai",
    "Tum please mujhe apna email address bhej do",
    "Aaj raat ko koi achi movie dekhte hain",
    "Main kal subah jaldi uthne ki try karunga",
    "Ye road construction ki wajah se band hai",
    "Mujhe lagta hai ke hum train se travel kar sakte hain",
    "Tumhara phone silent par kyun hai?",
    "Please mujhe remind kar dena ke kal assignment submit karna hai",
    "Aaj university mein students ki attendance bohat kam thi",
    "Main abhi apni presentation ki slides prepare kar raha hoon",
    "Kya tumhare paas extra pen hai?",
    "Yaar mujhe is topic ki basic understanding bhi nahi hai",
    "Tum ne lunch mein kya khaya?",
    "Main apna old phone sell karne ka soch raha hoon",
    "Ye application open hone mein bohat time leti hai",
    "Agar tum chaho to hum ye kaam together kar sakte hain",
    "Mujhe kal bank jana hai kuch important kaam ke liye",
    "Tum please lights off kar dena",
    "Aaj ka lecture bohat boring tha",
    "Main internet par iska solution search kar raha hoon",
    "Kya tum mujhe bata sakte ho ke ye kaise work karta hai?",
    "Yaar meri battery sirf 10 percent reh gayi hai",
    "Mujhe ek new keyboard aur mouse khareedna hai",
    "Tum itni jaldi ghar kyun ja rahe ho?",
    "Main usually raat ko 2 baje sota hoon",
    "Please apni location mujhe send kar do",
    "Aaj weather itna hot hai ke bahar jana mushkil hai",
    "Mujhe apne documents ki scanned copy chahiye",
    "Tum ne jo link bheja tha wo open nahi ho raha",
    "Main kal apne cousin ke ghar ja raha hoon",
    "Yaar mujhe ye song bohat pasand hai",
    "Kya hum is meeting ko kal shift kar sakte hain?",
    "Main abhi coding practice kar raha hoon",
    "Tumhara internet package kab expire ho raha hai?",
    "Mujhe lagta hai ke ye idea kaafi useful hai",
    "Please mujhe bata dena agar koi update aaye",
    "Aaj main thora late uth gaya tha",
    "Tum ne apni files properly save ki hain?",
    "Main is problem ka simple solution dhoond raha hoon",
    "Yaar kal ka exam kaafi difficult tha",
    "Kya tum mujhe apni notes ki pictures bhej sakte ho?",
    "Main abhi coffee bana raha hoon, tumhein bhi chahiye?",
    "Ye website mobile par properly work nahi kar rahi",
    "Tum mujhe kal morning mein call kar dena",
    "Mujhe apne future ke liye better planning karni hai",
    "Aaj friends ke saath bohat achi gathering hui",
    "Agar tum busy ho to koi problem nahi, baad mein baat kar lenge",
    "Main apna project deadline se pehle complete karna chahta hoon",
    "Tum ne computer restart karke dobara check kiya?",
    "Yaar mujhe aaj bilkul mood nahi hai parhna ka",
    "Please mujhe ye document PDF format mein send karna",
    "Main usually shopping online karta hoon because it saves time",
    "Tumhara idea interesting hai, isko try karna chahiye",
    "Aaj raat ko main thori der coding karunga",
    "Mujhe umeed hai ke kal ka din better hoga",
    "Chalo ab kaam start karte hain, warna deadline miss ho jayegi",
    # ... add your own extra/scraped sentences here too, if you want more than 150
]

# ---- STEP 2: common word dictionary (extend this as you go) ----
# Add more words here as you notice patterns — this list grows fast
URDU_WORDS = {
    "aaj","mera","meri","mood","nahi","hai","hoon","tha","thi","the","ka","ki","ke",
    "din","bohot","yaar","bhai","kal","ho","gaya","gayi","gaye","kya","kyun","kyunki",
    "mujhe","mujhse","usne","uska","uski","woh","yeh","ye","abhi","kuch","koi","sab",
    "raha","rahi","rahe","liya","diya","kar","karo","karna","karein","chahiye","zyada",
    "kam","bahar","ghar","phone","time","waqt","pata","samajh","dekho","suno","chalo",
    "theek","achha","acha","bura","garmi","sardi","khana","paani","log","insan"
}
ENGLISH_WORDS = {
    "for","anything","seriously","can","not","even","right","now","still","not",
    "prepared","at","all","was","waiting","for","you","finally","huge","relief",
    "would","say","that","stuck","hour","plan","bore","result","nervous","movie",
    "boring","waste","time","class","overslept","tension","everything","fine",
    "job","offer","believe","quiet","diet","start","talented","jealous","feel",
    "headache","meeting","thank","god","break","need","reply","rude","worth",
    "price","free","tomorrow","discuss","screen","crack","project","tired",
    "amazing","place","annoyed","getting","walk","explain","texted","guess",
    "said","down","since","morning","frustrating","gym","already","told","him",
    "dress","opinion","honest","bill","month","budget","tight","focus","today",
    "disappointed","recipe","try","well","signal","everyone","crazy","plan",
    "delay","flight","moving","city","miss","enough"
}

def clean_word(w):
    return re.sub(r"[^\w']", "", w).lower()

def auto_label(word):
    w = clean_word(word)
    if w in URDU_WORDS:
        return "URD"
    if w in ENGLISH_WORDS:
        return "ENG"
    return None  # unknown -> ask user

# ---- STEP 3: build labeled dataset (auto + interactive for unknowns) ----
data = []
for sentence in sentences:
    # Use regex so words split on punctuation too (commas, question marks, etc.)
    # This keeps contractions like "can't" and "it's" intact, but strips trailing punctuation
    words = re.findall(r"[A-Za-z']+", sentence)
    labels = []
    for w in words:
        guess = auto_label(w)
        if guess:
            labels.append(guess)
        else:
            # Only asks for words it doesn't recognize
            user_in = input(f"Label for '{w}' in \"{sentence}\" [URD/ENG/MIX] (default URD): ").strip().upper()
            labels.append(user_in if user_in in ("URD", "ENG", "MIX") else "URD")
    data.append({"sentence": sentence, "words": words, "labels": labels})

# ---- STEP 4: flatten to CSV (same as your assignment's format) ----
rows = []
for entry in data:
    for word, label in zip(entry["words"], entry["labels"]):
        rows.append({"sentence": entry["sentence"], "word": word, "label": label})

df = pd.DataFrame(rows)
df.to_csv("dataset.csv", index=False, encoding="utf-8")

print(f"Dataset created: {len(df)} word entries")
print(f"Sentences: {df.sentence.nunique()}")
print("Label distribution:")
print(df.label.value_counts())
# Out:
# Label for 'I' in "Yaar seriously I can't even right now, bohot thak gaya hoon" [URD/ENG/MIX] (default URD): ENG
# Label for 'can't' in "Yaar seriously I can't even right now, bohot thak gaya hoon" [URD/ENG/MIX] (default URD): ENG
# Label for 'thak' in "Yaar seriously I can't even right now, bohot thak gaya hoon" [URD/ENG/MIX] (default URD): URD
# Label for 'presentation' in "Bhai kal mera presentation hai, still not prepared at all" [URD/ENG/MIX] (default URD): ENG
# Label for 'kha' in "Khana kha liya? I was literally waiting for you" [URD/ENG/MIX] (default URD): URD
# Label for 'I' in "Khana kha liya? I was literally waiting for you" [URD/ENG/MIX] (default URD): ENG
# Label for 'literally' in "Khana kha liya? I was literally waiting for you" [URD/ENG/MIX] (default URD): ENG
# Label for 'Assignment' in "Assignment submit ho gaya finally, huge relief" [URD/ENG/MIX] (default URD): ENG
# ...
